# %%
import pandas as pd

# %%
import numpy as np

# %%
pokemon=pd.read_csv(r'C:\Users\pc\Downloads\pokemon123.csv',index_col='name').squeeze()

# %%
pokemon
# Out:
# name
# Bulbasaur       grass
# Ivysaur         grass
# Venusaur        grass
# Charmander       fire
# Charmeleon       fire
#                ...
# Celesteela      steel
# Kartana         grass
# Guzzlord         dark
# Necrozma      psychic
# Magearna        steel
# Name: type, Length: 801, dtype: object

# %%
value={
    'grass':'pet',
    'fire':'Danger',
    'water':'Charming',
    'psychic':'psycho',
    'steel':'robo'
} 
pokemon.map(value).head(50)
# Out:
# name
# Bulbasaur          pet
# Ivysaur            pet
# Venusaur           pet
# Charmander      Danger
# Charmeleon      Danger
# Charizard       Danger
# Squirtle      Charming
# Wartortle     Charming
# Blastoise     Charming
# Caterpie           NaN
# Metapod            NaN
# Butterfree         NaN
# Weedle             NaN
# Kakuna             NaN
# Beedrill           NaN
# Pidgey             NaN
# Pidgeotto          NaN
# Pidgeot            NaN
# Rattata            NaN
# Raticate           NaN
# Spearow            NaN
# Fearow             NaN
# Ekans              NaN
# Arbok              NaN
# Pikachu            NaN
# Raichu             NaN
# Sandshrew          NaN
# Sandslash          NaN
# Nidoran♀           NaN
# Nidorina           NaN
# Nidoqueen          NaN
# Nidoran♂           NaN
# Nidorino           NaN
# Nidoking           NaN
# Clefairy           NaN
# Clefable           NaN
# Vulpix          Danger
# Ninetales       Danger
# Jigglypuff         NaN
# ...

# %%
nba=pd.read_csv(r'C:\Users\pc\Downloads\nba.csv')

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
student={
    'Name':['Amit','Sumit','Kamal'],
    'Adress':['Moti Nagar','Ram Nagar','Kamala nagar'],
    'City':['Delhi','Chennai','Manipur']
}

# %%
student
# Out:
# {'Name': ['Amit', 'Sumit', 'Kamal'],
#  'Adress': ['Moti Nagar', 'Ram Nagar', 'Kamala nagar'],
#  'City': ['Delhi', 'Chennai', 'Manipur']}

# %%
df=pd.DataFrame(student)

# %%
df
# Out:
#     Name        Adress     City
# 0   Amit    Moti Nagar    Delhi
# 1  Sumit     Ram Nagar  Chennai
# 2  Kamal  Kamala nagar  Manipur

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0, ..., 180, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99, ..., 235, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30, ..., 205,
#         'Boston University', nan],
#        ...,
#        ['Raul Neto', 'Utah Jazz', 25, ..., 179, nan, 900000.0],
#        ['Tibor Pleiss', 'Utah Jazz', 21, ..., 256, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24, ..., 231, 'Kansas', 947276.0]],
#       shape=(457, 9), dtype=object)

# %%
nba.size
# Out:
# 4113

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.shape
# Out:
# (457, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
nba=pd.read_csv(r'C:\Users\pc\Downloads\nba.csv',index_col=['Name'])

# %%
nba
# Out:
#                          Team  Number Position  Age  Height  Weight  \
# Name
# Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# Jae Crowder    Boston Celtics      99       SF   25   6-Jun     235
# John Holland   Boston Celtics      30       SG   27   5-Jun     205
# R.J. Hunter    Boston Celtics      28       SG   22   5-Jun     185
# Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ...                       ...     ...      ...  ...     ...     ...
# Trey Lyles          Utah Jazz      41       PF   20  10-Jun     234
# Shelvin Mack        Utah Jazz       8       PG   26   3-Jun     203
# Raul Neto           Utah Jazz      25       PG   24   1-Jun     179
# Tibor Pleiss        Utah Jazz      21        C   26   3-Jul     256
# Jeff Withey         Utah Jazz      24        C   26  Jul-00     231
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
nba.index
# Out:
# Index(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#        'Jonas Jerebko', 'Amir Johnson', 'Jordan Mickey', 'Kelly Olynyk',
#        'Terry Rozier', 'Marcus Smart',
#        ...
#        'Rudy Gobert', 'Gordon Hayward', 'Rodney Hood', 'Joe Ingles',
#        'Chris Johnson', 'Trey Lyles', 'Shelvin Mack', 'Raul Neto',
#        'Tibor Pleiss', 'Jeff Withey'],
#       dtype='object', name='Name', length=457)

# %%
nba.axes
# Out:
# [Index(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#         'Jonas Jerebko', 'Amir Johnson', 'Jordan Mickey', 'Kelly Olynyk',
#         'Terry Rozier', 'Marcus Smart',
#         ...
#         'Rudy Gobert', 'Gordon Hayward', 'Rodney Hood', 'Joe Ingles',
#         'Chris Johnson', 'Trey Lyles', 'Shelvin Mack', 'Raul Neto',
#         'Tibor Pleiss', 'Jeff Withey'],
#        dtype='object', name='Name', length=457),
#  Index(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#         'Salary'],
#        dtype='object')]

# %%
nba.head(50)
# Out:
#                                        Team  Number Position  Age  Height  \
# Name
# Avery Bradley                Boston Celtics       0       PG   25   2-Jun
# Jae Crowder                  Boston Celtics      99       SF   25   6-Jun
# John Holland                 Boston Celtics      30       SG   27   5-Jun
# R.J. Hunter                  Boston Celtics      28       SG   22   5-Jun
# Jonas Jerebko                Boston Celtics       8       PF   29  10-Jun
# Amir Johnson                 Boston Celtics      90       PF   29   9-Jun
# Jordan Mickey                Boston Celtics      55       PF   21   8-Jun
# Kelly Olynyk                 Boston Celtics      41        C   25  Jul-00
# Terry Rozier                 Boston Celtics      12       PG   22   2-Jun
# Marcus Smart                 Boston Celtics      36       PG   22   4-Jun
# Jared Sullinger              Boston Celtics       7        C   24   9-Jun
# Isaiah Thomas                Boston Celtics       4       PG   27   9-May
# ...
