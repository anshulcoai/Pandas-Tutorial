# %%
import pandas as pd

# %%
import numpy as np

# %%
emp=pd.read_csv(r'C:\Users\pc\Downloads\employees.csv')

# %%
emp.dropna(how='all',inplace=True)

# %%
emp
# Out:
#      First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0       Douglas    Male    8/6/1993        12:42 PM   97308.0    6.945
# 1        Thomas    Male   3/31/1996         6:53 AM   61933.0    4.170
# 3         Maria  Female   4/23/1993        11:17 AM  130590.0   11.858
# 4         Jerry    Male    3/4/2005         1:00 PM  138705.0    9.340
# 5         Larry    Male   1/24/1998         4:47 PM  101004.0    1.389
# ...         ...     ...         ...             ...       ...      ...
# 996       Henry     NaN  11/23/2014         6:09 AM  132483.0   16.655
# 997     Phillip    Male   1/31/1984         6:30 AM   42392.0   19.675
# 998     Russell    Male   5/20/2013        12:39 PM   96914.0    1.421
# 999       Larry    Male   4/20/2013         4:45 PM   60500.0   11.985
# 1000     Albert    Male   5/15/2012         6:24 PM  129949.0   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   float64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 70.3+ KB

# %%
emp=emp.fillna('Not Known')

# %%
emp
# Out:
#      First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0       Douglas       Male    8/6/1993        12:42 PM   97308.0    6.945
# 1        Thomas       Male   3/31/1996         6:53 AM   61933.0    4.170
# 3         Maria     Female   4/23/1993        11:17 AM  130590.0   11.858
# 4         Jerry       Male    3/4/2005         1:00 PM  138705.0    9.340
# 5         Larry       Male   1/24/1998         4:47 PM  101004.0    1.389
# ...         ...        ...         ...             ...       ...      ...
# 996       Henry  Not Known  11/23/2014         6:09 AM  132483.0   16.655
# 997     Phillip       Male   1/31/1984         6:30 AM   42392.0   19.675
# 998     Russell       Male   5/20/2013        12:39 PM   96914.0    1.421
# 999       Larry       Male   4/20/2013         4:45 PM   60500.0   11.985
# 1000     Albert       Male   5/15/2012         6:24 PM  129949.0   10.169
#
#      Senior Management                  Team
# ...

# %%
emp.nunique()
# Out:
# First Name           201
# Gender                 3
# Start Date           972
# Last Login Time      720
# Salary               995
# Bonus %              971
# Senior Management      3
# Team                  11
# dtype: int64

# %%
emp['Team']=emp['Team'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   float64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   object
#  7   Team               1000 non-null   category
# dtypes: category(1), float64(2), object(5)
# memory usage: 63.9+ KB

# %%
emp
# Out:
#      First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0       Douglas       Male    8/6/1993        12:42 PM   97308.0    6.945
# 1        Thomas       Male   3/31/1996         6:53 AM   61933.0    4.170
# 3         Maria     Female   4/23/1993        11:17 AM  130590.0   11.858
# 4         Jerry       Male    3/4/2005         1:00 PM  138705.0    9.340
# 5         Larry       Male   1/24/1998         4:47 PM  101004.0    1.389
# ...         ...        ...         ...             ...       ...      ...
# 996       Henry  Not Known  11/23/2014         6:09 AM  132483.0   16.655
# 997     Phillip       Male   1/31/1984         6:30 AM   42392.0   19.675
# 998     Russell       Male   5/20/2013        12:39 PM   96914.0    1.421
# 999       Larry       Male   4/20/2013         4:45 PM   60500.0   11.985
# 1000     Albert       Male   5/15/2012         6:24 PM  129949.0   10.169
#
#      Senior Management                  Team
# ...

# %%
emp['Salary']=emp['Salary'].astype('int')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   object
#  7   Team               1000 non-null   category
# dtypes: category(1), float64(1), int64(1), object(5)
# memory usage: 63.9+ KB

# %%
emp['Gender']=emp['Gender'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   category
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   object
#  7   Team               1000 non-null   category
# dtypes: category(2), float64(1), int64(1), object(4)
# memory usage: 57.1+ KB

# %%
emp
# Out:
#      First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1        Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 3         Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 4         Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 5         Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ...         ...        ...         ...             ...     ...      ...
# 996       Henry  Not Known  11/23/2014         6:09 AM  132483   16.655
# 997     Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 998     Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 999       Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 1000     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp.sort_values(by='Team')
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 753       Henry    Male  2/23/2007         3:24 AM   49665   18.338
# 488      Cheryl  Female  12/3/2014         9:27 AM   71751   15.918
# 100      Harold    Male   1/2/1985         9:40 PM   77544   12.447
# 345       Scott    Male  5/12/2009         4:36 AM   58248    3.914
# 717        Eric    Male  6/15/1993         3:56 AM   51070   13.806
# ...         ...     ...        ...             ...     ...      ...
# 341      Steven    Male  5/12/2009         2:14 PM  113060    2.846
# 338        Earl    Male   1/5/2000         5:46 PM   91344    4.035
# 874       Jason    Male   5/1/1998         6:05 PM   75607    4.299
# 387     Phyllis  Female  1/15/1995         5:27 AM  125881   16.697
# 1000     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 753              False  Business Development
# 488              False  Business Development
# ...

# %%
emp
# Out:
#      First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1        Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 3         Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 4         Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 5         Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ...         ...        ...         ...             ...     ...      ...
# 996       Henry  Not Known  11/23/2014         6:09 AM  132483   16.655
# 997     Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 998     Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 999       Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 1000     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp.sort_values(by=['Team','First Name','Salary'],ascending=[True,True,False],inplace=True)

# %%
emp.head(50)
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 478     Albert       Male   8/14/2008         5:43 PM  137840    9.705
# 960     Albert       Male   9/19/1992         2:35 AM   45094    5.850
# 119     Andrea     Female   1/12/2012         5:43 AM  120204    9.557
# 591     Andrea     Female  10/30/1994        11:23 AM   87575   13.346
# 510        Ann     Female   11/4/1984        12:17 PM   90719    6.220
# 87       Annie  Not Known   9/29/2007        12:11 AM  103495   17.290
# 130    Antonio       Male  10/25/1988         1:50 PM   60866   13.101
# 923     Arthur       Male   12/5/2013         8:44 AM   86615    3.412
# 115     Ashley     Female    8/4/2002        11:00 AM   58698    6.811
# 736    Barbara     Female  11/26/2002         5:32 AM   82884    6.837
# 250      Betty     Female   6/12/2002         3:59 AM  104896   19.550
# 112     Bonnie     Female  12/17/1999         3:12 PM   42153    8.454
# ...

# %%
emp
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 478     Albert       Male   8/14/2008         5:43 PM  137840    9.705
# 960     Albert       Male   9/19/1992         2:35 AM   45094    5.850
# 119     Andrea     Female   1/12/2012         5:43 AM  120204    9.557
# 591     Andrea     Female  10/30/1994        11:23 AM   87575   13.346
# 510        Ann     Female   11/4/1984        12:17 PM   90719    6.220
# ..         ...        ...         ...             ...     ...      ...
# 351     Thomas  Not Known   8/31/1995         8:31 PM   41549    3.950
# 610       Todd       Male   2/16/2010        11:29 AM  103405   15.910
# 973     Victor  Not Known   7/28/2006         2:49 PM   76381   11.159
# 897     Victor       Male   3/10/2010         5:01 PM   45267    3.942
# 467     Walter       Male    8/4/2007         1:59 PM   58789    5.461
#
#     Senior Management                  Team
# 478             False  Business Development
# ...

# %%
emp.sort_index(inplace=True)

# %%
emp
# Out:
#      First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1        Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 3         Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 4         Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 5         Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ...         ...        ...         ...             ...     ...      ...
# 996       Henry  Not Known  11/23/2014         6:09 AM  132483   16.655
# 997     Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 998     Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 999       Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 1000     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   category
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   object
#  7   Team               1000 non-null   category
# dtypes: category(2), float64(1), int64(1), object(4)
# memory usage: 57.1+ KB

# %%
emp['Rank_Salary']=emp['Salary'].rank()

# %%
emp
# Out:
#      First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1        Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 3         Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 4         Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 5         Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ...         ...        ...         ...             ...     ...      ...
# 996       Henry  Not Known  11/23/2014         6:09 AM  132483   16.655
# 997     Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 998     Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 999       Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 1000     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team  Rank_Salary
# ...

# %%
a=emp['Rank_Salary'].astype('int')

# %%
a.head(50)
# Out:
# 0     566
# 1     245
# 3     848
# 4     911
# 5     601
# 6     727
# 7     277
# 8     104
# 9     550
# 10    918
# 11    258
# 12    609
# 13    701
# 14    677
# 15     57
# 16    225
# 17    499
# 18    693
# 19    868
# 20    409
# 21    271
# 22    595
# 23    506
# 24    819
# 25    576
# 26     23
# 27     26
# 28    784
# 29    801
# 30    398
# 31    752
# 32    485
# 33    783
# 34    756
# 35    552
# 36    448
# 37    942
# 38    203
# 39     19
# 40    781
# 41    589
# 42    288
# 43    779
# 44    350
# 45    964
# 46    482
# 47    720
# 48    293
# 49    531
# 50    708
# Name: Rank_Salary, dtype: int64

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   category
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   object
#  7   Team               1000 non-null   category
#  8   Rank_Salary        1000 non-null   float64
# dtypes: category(2), float64(2), int64(1), object(4)
# memory usage: 65.0+ KB

# %%
emp['Start Date']=pd.to_datetime(emp['Start Date'])

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   object
#  7   Team               1000 non-null   category
#  8   Rank_Salary        1000 non-null   float64
# dtypes: category(2), datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 65.0+ KB

# %%
emp=pd.read_csv(r'C:\Users\pc\Downloads\employees.csv',parse_dates=["Start Date","Last Login Time"])
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12256\4013834794.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   emp=pd.read_csv(r'C:\Users\pc\Downloads\employees.csv',parse_dates=["Start Date","Last Login Time"])

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   float64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(2), object(4)
# memory usage: 62.7+ KB

# %%
emp.dropna(how='all')
# Out:
#      First Name  Gender Start Date     Last Login Time    Salary  Bonus %  \
# 0       Douglas    Male 1993-08-06 2025-02-18 12:42:00   97308.0    6.945
# 1        Thomas    Male 1996-03-31 2025-02-18 06:53:00   61933.0    4.170
# 3         Maria  Female 1993-04-23 2025-02-18 11:17:00  130590.0   11.858
# 4         Jerry    Male 2005-03-04 2025-02-18 13:00:00  138705.0    9.340
# 5         Larry    Male 1998-01-24 2025-02-18 16:47:00  101004.0    1.389
# ...         ...     ...        ...                 ...       ...      ...
# 996       Henry     NaN 2014-11-23 2025-02-18 06:09:00  132483.0   16.655
# 997     Phillip    Male 1984-01-31 2025-02-18 06:30:00   42392.0   19.675
# 998     Russell    Male 2013-05-20 2025-02-18 12:39:00   96914.0    1.421
# 999       Larry    Male 2013-04-20 2025-02-18 16:45:00   60500.0   11.985
# 1000     Albert    Male 2012-05-15 2025-02-18 18:24:00  129949.0   10.169
#
#      Senior Management                  Team
# ...

# %%
emp['Salary']=emp['Salary'].fillna(0)

# %%
emp['Senior Management']=emp['Senior Management'].astype('bool')
emp['Salary']=emp['Salary'].astype('int')
emp['Team']=emp['Team'].astype('category')
emp['Gender']=emp['Gender'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1001 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1001 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.7+ KB
