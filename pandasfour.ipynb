# %%
import pandas as pd

# %%
import numpy as np

# %%
nba=pd.read_csv(r'C:\Users\pc\Downloads\nba.csv')

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
type(nba['Name'])
# Out:
# pandas.core.series.Series

# %%
nba[['Name','Number','Position','Age']]
# Out:
#               Name  Number Position  Age
# 0    Avery Bradley       0       PG   25
# 1      Jae Crowder      99       SF   25
# 2     John Holland      30       SG   27
# 3      R.J. Hunter      28       SG   22
# 4    Jonas Jerebko       8       PF   29
# ..             ...     ...      ...  ...
# 452     Trey Lyles      41       PF   20
# 453   Shelvin Mack       8       PG   26
# 454      Raul Neto      25       PG   24
# 455   Tibor Pleiss      21        C   26
# 456    Jeff Withey      24        C   26
#
# [457 rows x 4 columns]

# %%
#multi Columnar Data
type(nba[['Name','Number','Position']])
# Out:
# pandas.core.frame.DataFrame

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba['Age After 3 Years']=nba['Age']+3

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary  Age After 3 Years
# ...

# %%
nba['Event']='Champions Trophy'

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary  Age After 3 Years             Event
# ...

# %%
nba.insert(loc=8,column='Weight after 3 pound increment',value=nba['Weight']+3)

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College  Weight after 3 pound increment     Salary  \
# ...

# %%
nba['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
nba['Position'].value_counts(normalize=True)*100
# Out:
# Position
# SG    22.319475
# PF    21.881838
# PG    20.131291
# SF    18.599562
# C     17.067834
# Name: proportion, dtype: float64

# %%
nba['Salary'].max()
# Out:
# np.float64(25000000.0)

# %%
nba.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  \
# 0    False  False   False     False  False   False   False    False
# 1    False  False   False     False  False   False   False    False
# 2    False  False   False     False  False   False   False    False
# 3    False  False   False     False  False   False   False    False
# 4    False  False   False     False  False   False   False     True
# ..     ...    ...     ...       ...    ...     ...     ...      ...
# 452  False  False   False     False  False   False   False    False
# 453  False  False   False     False  False   False   False    False
# 454  False  False   False     False  False   False   False     True
# 455  False  False   False     False  False   False   False     True
# 456  False  False   False     False  False   False   False    False
#
#      Weight after 3 pound increment  Salary  Age After 3 Years  Event
# 0                             False   False              False  False
# ...

# %%
#data filtering using is null
#find out all player name whose colleges name is missing
col=pd.isnull(nba['College'])
nba[col]
# Out:
#                        Name             Team  Number Position  Age  Height  \
# 4             Jonas Jerebko   Boston Celtics       8       PF   29  10-Jun
# 5              Amir Johnson   Boston Celtics      90       PF   29   9-Jun
# 15         Bojan Bogdanovic    Brooklyn Nets      44       SG   27   8-Jun
# 20           Sergey Karasev    Brooklyn Nets      10       SG   22   7-Jun
# 32   Thanasis Antetokounmpo  New York Knicks      43       SF   23   7-Jun
# ..                      ...              ...     ...      ...  ...     ...
# 445              Dante Exum        Utah Jazz      11       PG   20   6-Jun
# 447             Rudy Gobert        Utah Jazz      27        C   23   1-Jul
# 450              Joe Ingles        Utah Jazz       2       SF   28   8-Jun
# 454               Raul Neto        Utah Jazz      25       PG   24   1-Jun
# 455            Tibor Pleiss        Utah Jazz      21        C   26   3-Jul
#
#      Weight College  Weight after 3 pound increment      Salary  \
# ...
