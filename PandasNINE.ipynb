# %%
import pandas as pd

# %%
movies=pd.read_csv(r'C:\Users\pc\Downloads\movies.csv',
                  index_col='Film')

# %%
movies
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, Dr. No to Spectre
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               26 non-null     int64
#  1   Actor              26 non-null     object
#  2   Director           26 non-null     object
#  3   Box Office         26 non-null     float64
#  4   Budget             26 non-null     float64
#  5   Bond Actor Salary  18 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.4+ KB

# %%
movies.fillna(0,inplace=True)

# %%
movies
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, Dr. No to Spectre
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               26 non-null     int64
#  1   Actor              26 non-null     object
#  2   Director           26 non-null     object
#  3   Box Office         26 non-null     float64
#  4   Budget             26 non-null     float64
#  5   Bond Actor Salary  26 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.4+ KB

# %%
movies
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
movies[movies['Year']==1962]
# Out:
#         Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No  1962  Sean Connery  Terence Young       448.8     7.0
#
#         Bond Actor Salary
# Film
# Dr. No                0.6

# %%
movies.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                0.0
# Casino Royale                3.3

# %%
movies.iloc[3]
# Out:
# Year                          1965
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   848.1
# Budget                        41.9
# Bond Actor Salary              4.7
# Name: Thunderball, dtype: object

# %%
movies.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                0.0
# Casino Royale                3.3

# %%
movies.iloc[5]
# Out:
# Year                          1967
# Actor                 Sean Connery
# Director             Lewis Gilbert
# Box Office                   514.2
# Budget                        59.9
# Bond Actor Salary              4.4
# Name: You Only Live Twice, dtype: object

# %%
movies
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
#movies detail from thunderball to live and let die
movies.loc['Thunderball':'Live and Let Die']
# Out:
#                                  Year           Actor       Director  \
# Film
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
# Live and Let Die                 1973     Roger Moore   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                0.0
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8
# ...

# %%
movies.iloc[3:8]
# Out:
#                                  Year           Actor       Director  \
# Film
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                0.0
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8

# %%
movies.loc[:'Thunderball']
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %%
movies.loc['Thunderball':]
# Out:
#                                  Year           Actor            Director  \
# Film
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# For Your Eyes Only               1981     Roger Moore           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# ...

# %%
# record from thunderball to last by skippin 3
movies.loc['Thunderball'::3]
# Out:
#                                  Year           Actor         Director  \
# Film
# Thunderball                      1965    Sean Connery    Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# The Man with the Golden Gun      1974     Roger Moore     Guy Hamilton
# For Your Eyes Only               1981     Roger Moore        John Glen
# A View to a Kill                 1985     Roger Moore        John Glen
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Skyfall                          2012    Daniel Craig       Sam Mendes
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Thunderball                           848.1    41.9                4.7
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Man with the Golden Gun           334.0    27.7                0.0
# ...

# %%
movies.iloc[4:10]
# Out:
#                                  Year           Actor       Director  \
# Film
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
# Live and Let Die                 1973     Roger Moore   Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Casino Royale                         315.0    85.0                0.0
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8
# Live and Let Die                      460.3    30.8                0.0
# ...

# %%
movies.loc['Thunderball','Box Office']
# Out:
# np.float64(848.1)

# %%
movies.loc['Thunderball',['Box Office','Budget']]
# Out:
# Box Office    848.1
# Budget         41.9
# Name: Thunderball, dtype: object

# %%
movies.loc[['Thunderball','Spectre'],['Box Office','Budget',]]
# Out:
#              Box Office  Budget
# Film
# Thunderball       848.1    41.9
# Spectre           726.7   206.3

# %%
#Change Movie Name Thunderball to Thunder ball
movies.rename(mapper={'Thunderball':'Thunder ball'},inplace=True)

# %%
movies
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunder ball                     1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
movies.rename(mapper={'Goldfinger':'Gold Finger'},inplace=True)

# %%
movies
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Gold Finger                      1964    Sean Connery        Guy Hamilton
# Thunder ball                     1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
movies.rename(mapper={'Gold Finger':'GoldFinger','Thunder ball':'ThunderBall'},inplace=True)

# %%
movies
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldFinger                       1964    Sean Connery        Guy Hamilton
# ThunderBall                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
actor=movies['Actor']=='Sean Connery'

# %%
movies.loc[actor,'Actor']=='Sir Sean connery'
# Out:
# Film
# Dr. No                   False
# From Russia with Love    False
# GoldFinger               False
# ThunderBall              False
# You Only Live Twice      False
# Diamonds Are Forever     False
# Never Say Never Again    False
# Name: Actor, dtype: bool

# %%
movies
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldFinger                       1964    Sean Connery        Guy Hamilton
# ThunderBall                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
movies.rename(mapper={'Year':'Release Year','Box Office':'Collection'},axis=1)
# Out:
#                                  Release Year           Actor  \
# Film
# Dr. No                                   1962    Sean Connery
# From Russia with Love                    1963    Sean Connery
# GoldFinger                               1964    Sean Connery
# ThunderBall                              1965    Sean Connery
# Casino Royale                            1967     David Niven
# You Only Live Twice                      1967    Sean Connery
# On Her Majesty's Secret Service          1969  George Lazenby
# Diamonds Are Forever                     1971    Sean Connery
# Live and Let Die                         1973     Roger Moore
# The Man with the Golden Gun              1974     Roger Moore
# The Spy Who Loved Me                     1977     Roger Moore
# Moonraker                                1979     Roger Moore
# For Your Eyes Only                       1981     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
movies.rename(mapper={'Year':'Release Year','Box Office':'Collection'},axis=1,inplace=True)

# %%
movies
# Out:
#                                  Release Year           Actor  \
# Film
# Dr. No                                   1962    Sean Connery
# From Russia with Love                    1963    Sean Connery
# GoldFinger                               1964    Sean Connery
# ThunderBall                              1965    Sean Connery
# Casino Royale                            1967     David Niven
# You Only Live Twice                      1967    Sean Connery
# On Her Majesty's Secret Service          1969  George Lazenby
# Diamonds Are Forever                     1971    Sean Connery
# Live and Let Die                         1973     Roger Moore
# The Man with the Golden Gun              1974     Roger Moore
# The Spy Who Loved Me                     1977     Roger Moore
# Moonraker                                1979     Roger Moore
# For Your Eyes Only                       1981     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
movies.drop('Spectre')
# Out:
#                                  Release Year           Actor  \
# Film
# Dr. No                                   1962    Sean Connery
# From Russia with Love                    1963    Sean Connery
# GoldFinger                               1964    Sean Connery
# ThunderBall                              1965    Sean Connery
# Casino Royale                            1967     David Niven
# You Only Live Twice                      1967    Sean Connery
# On Her Majesty's Secret Service          1969  George Lazenby
# Diamonds Are Forever                     1971    Sean Connery
# Live and Let Die                         1973     Roger Moore
# The Man with the Golden Gun              1974     Roger Moore
# The Spy Who Loved Me                     1977     Roger Moore
# Moonraker                                1979     Roger Moore
# For Your Eyes Only                       1981     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
movies.drop('Spectre',inplace=True)

# %%
movies
# Out:
#                                  Release Year           Actor  \
# Film
# Dr. No                                   1962    Sean Connery
# From Russia with Love                    1963    Sean Connery
# GoldFinger                               1964    Sean Connery
# ThunderBall                              1965    Sean Connery
# Casino Royale                            1967     David Niven
# You Only Live Twice                      1967    Sean Connery
# On Her Majesty's Secret Service          1969  George Lazenby
# Diamonds Are Forever                     1971    Sean Connery
# Live and Let Die                         1973     Roger Moore
# The Man with the Golden Gun              1974     Roger Moore
# The Spy Who Loved Me                     1977     Roger Moore
# Moonraker                                1979     Roger Moore
# For Your Eyes Only                       1981     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
del movies['Collection']

# %%
movies
# Out:
#                                  Release Year           Actor  \
# Film
# Dr. No                                   1962    Sean Connery
# From Russia with Love                    1963    Sean Connery
# GoldFinger                               1964    Sean Connery
# ThunderBall                              1965    Sean Connery
# Casino Royale                            1967     David Niven
# You Only Live Twice                      1967    Sean Connery
# On Her Majesty's Secret Service          1969  George Lazenby
# Diamonds Are Forever                     1971    Sean Connery
# Live and Let Die                         1973     Roger Moore
# The Man with the Golden Gun              1974     Roger Moore
# The Spy Who Loved Me                     1977     Roger Moore
# Moonraker                                1979     Roger Moore
# For Your Eyes Only                       1981     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
movies.pop('Release Year')
# Out:
# Film
# Dr. No                             1962
# From Russia with Love              1963
# GoldFinger                         1964
# ThunderBall                        1965
# Casino Royale                      1967
# You Only Live Twice                1967
# On Her Majesty's Secret Service    1969
# Diamonds Are Forever               1971
# Live and Let Die                   1973
# The Man with the Golden Gun        1974
# The Spy Who Loved Me               1977
# Moonraker                          1979
# For Your Eyes Only                 1981
# Never Say Never Again              1983
# Octopussy                          1983
# A View to a Kill                   1985
# The Living Daylights               1987
# Licence to Kill                    1989
# GoldenEye                          1995
# Tomorrow Never Dies                1997
# The World Is Not Enough            1999
# Die Another Day                    2002
# Casino Royale                      2006
# ...

# %%
movies
# Out:
#                                           Actor            Director  Budget  \
# Film
# Dr. No                             Sean Connery       Terence Young     7.0
# From Russia with Love              Sean Connery       Terence Young    12.6
# GoldFinger                         Sean Connery        Guy Hamilton    18.6
# ThunderBall                        Sean Connery       Terence Young    41.9
# Casino Royale                       David Niven          Ken Hughes    85.0
# You Only Live Twice                Sean Connery       Lewis Gilbert    59.9
# On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt    37.3
# Diamonds Are Forever               Sean Connery        Guy Hamilton    34.7
# Live and Let Die                    Roger Moore        Guy Hamilton    30.8
# The Man with the Golden Gun         Roger Moore        Guy Hamilton    27.7
# The Spy Who Loved Me                Roger Moore       Lewis Gilbert    45.1
# ...

# %%
#To Get Random row from data
movies.sample()
# Out:
#                               Actor       Director  Budget  Bond Actor Salary
# Film
# From Russia with Love  Sean Connery  Terence Young    12.6                1.6

# %%
movies.sample()
# Out:
#                 Actor    Director  Budget  Bond Actor Salary
# Film
# Skyfall  Daniel Craig  Sam Mendes   170.2               14.5

# %%
movies.sample(3)
# Out:
#                                Actor       Director  Budget  Bond Actor Salary
# Film
# Diamonds Are Forever    Sean Connery   Guy Hamilton    34.7                5.8
# Moonraker                Roger Moore  Lewis Gilbert    91.5                0.0
# The Living Daylights  Timothy Dalton      John Glen    68.8                5.2

# %%
movies.sample(5)
# Out:
#                                Actor            Director  Budget  \
# Film
# Tomorrow Never Dies   Pierce Brosnan  Roger Spottiswoode   133.9
# Octopussy                Roger Moore           John Glen    53.9
# GoldFinger              Sean Connery        Guy Hamilton    18.6
# You Only Live Twice     Sean Connery       Lewis Gilbert    59.9
# The Spy Who Loved Me     Roger Moore       Lewis Gilbert    45.1
#
#                       Bond Actor Salary
# Film
# Tomorrow Never Dies                10.0
# Octopussy                           7.8
# GoldFinger                          3.2
# You Only Live Twice                 4.4
# The Spy Who Loved Me                0.0

# %%
movies.sample(frac=0.25)
# Out:
#                                           Actor        Director  Budget  \
# Film
# The Man with the Golden Gun         Roger Moore    Guy Hamilton    27.7
# ThunderBall                        Sean Connery   Terence Young    41.9
# On Her Majesty's Secret Service  George Lazenby   Peter R. Hunt    37.3
# The World Is Not Enough          Pierce Brosnan   Michael Apted   158.3
# Never Say Never Again              Sean Connery  Irvin Kershner    86.0
# From Russia with Love              Sean Connery   Terence Young    12.6
#
#                                  Bond Actor Salary
# Film
# The Man with the Golden Gun                    0.0
# ThunderBall                                    4.7
# On Her Majesty's Secret Service                0.6
# The World Is Not Enough                       13.5
# Never Say Never Again                          0.0
# From Russia with Love                          1.6

# %%
movies.sample(frac=0.5)
# Out:
#                                   Actor            Director  Budget  \
# Film
# Tomorrow Never Dies      Pierce Brosnan  Roger Spottiswoode   133.9
# Moonraker                   Roger Moore       Lewis Gilbert    91.5
# GoldFinger                 Sean Connery        Guy Hamilton    18.6
# Diamonds Are Forever       Sean Connery        Guy Hamilton    34.7
# Licence to Kill          Timothy Dalton           John Glen    56.7
# A View to a Kill            Roger Moore           John Glen    54.5
# GoldenEye                Pierce Brosnan     Martin Campbell    76.9
# From Russia with Love      Sean Connery       Terence Young    12.6
# Skyfall                    Daniel Craig          Sam Mendes   170.2
# For Your Eyes Only          Roger Moore           John Glen    60.2
# Casino Royale              Daniel Craig     Martin Campbell   145.3
# The World Is Not Enough  Pierce Brosnan       Michael Apted   158.3
#
#                          Bond Actor Salary
# Film
# ...

# %%
#movies details with highest budget
movies.nlargest(1,'Budget')
# Out:
#                           Actor      Director  Budget  Bond Actor Salary
# Film
# Quantum of Solace  Daniel Craig  Marc Forster   181.4                8.1

# %%
#movies details with lowest budget
movies.nsmallest(5,'Budget')
# Out:
#                                     Actor       Director  Budget  \
# Film
# Dr. No                       Sean Connery  Terence Young     7.0
# From Russia with Love        Sean Connery  Terence Young    12.6
# GoldFinger                   Sean Connery   Guy Hamilton    18.6
# The Man with the Golden Gun   Roger Moore   Guy Hamilton    27.7
# Live and Let Die              Roger Moore   Guy Hamilton    30.8
#
#                              Bond Actor Salary
# Film
# Dr. No                                     0.6
# From Russia with Love                      1.6
# GoldFinger                                 3.2
# The Man with the Golden Gun                0.0
# Live and Let Die                           0.0

# %%
#Top 5 highest budgte film
movies.nlargest(5,'Budget')
# Out:
#                                   Actor         Director  Budget  \
# Film
# Quantum of Solace          Daniel Craig     Marc Forster   181.4
# Skyfall                    Daniel Craig       Sam Mendes   170.2
# The World Is Not Enough  Pierce Brosnan    Michael Apted   158.3
# Die Another Day          Pierce Brosnan     Lee Tamahori   154.2
# Casino Royale              Daniel Craig  Martin Campbell   145.3
#
#                          Bond Actor Salary
# Film
# Quantum of Solace                      8.1
# Skyfall                               14.5
# The World Is Not Enough               13.5
# Die Another Day                       17.9
# Casino Royale                          3.3
